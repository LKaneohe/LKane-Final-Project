# %%
#Lilia Kane Final Project  

import pandas as pd
import numpy as np


import os

path = os.getcwd()

print(path)
file_path = path + "/" + "Global_Earthquake_Data.csv"
#print (file_path)

quakes = pd.read_csv(file_path)

#print(quakes.head())
#select relevant columns (time, lat, long, depth, mag, magnitud type, number of stations, dmin, magNst, rms, place)

dfquakes = quakes[['time', 'latitude', 'longitude', 'depth', 'mag', 'nst', 'dmin', 'rms', 'place']]
print(dfquakes.head())
# Out:
# /Users/Lilia/myProject
#                        time  latitude  longitude    depth  mag    nst   dmin  \
# 0  2023-02-26T23:58:05.052Z   41.8050    79.8675   10.000  5.0   46.0  1.293
# 1  2023-02-26T23:33:17.641Z   18.7420   145.4868  200.365  4.8   67.0  5.158
# 2  2023-02-26T21:42:14.541Z   42.0857    79.9516   10.000  4.9   45.0  1.223
# 3  2023-02-26T21:35:01.303Z   14.9364  -104.5563   10.000  4.6   51.0  5.661
# 4  2023-02-26T18:58:54.828Z   44.6730   146.5159  134.299  4.5  108.0  2.866
#
#     rms                                   place
# 0  0.80                77 km NNW of Aksu, China
# 1  0.95  Pagan region, Northern Mariana Islands
# 2  0.82                                     NaN
# 3  0.57              northern East Pacific Rise
# 4  0.82              84 km NE of Otrada, Russia

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr 

import os
path = os.getcwd()

#print(path)
file_path = path + "/" + "Global_Earthquake_Data.csv"
#print (file_path)

df_eq = pd.read_csv(file_path)
df_eq['time'] = pd.to_datetime(df_eq['time'])

df_eq.set_index('time', inplace=True)

df_eq.head()

plt.title("Deep and Shallow Earthquakes")

df_eq.plot.scatter(x='depth',
                      y='mag')
#histogram
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.histplot(df_eq['mag'], bins=30, kde=True)
plt.title('Earthquakes by Depth')
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.show()



#barplot
#quake_count = df_eq['mag'].value_counts()
#sns.barplot(x = df_eq['time'].value_counts(), y = quake_count, color="yellow")
#plt.title('Number of Earthquakes Last Century')
#plt.xlabel('Magnitude')
#plt.ylabel('Number of Erthquakes')
#plt.show()

#shallow = df_eq['depth'] < 50]['mag'].values]
#deep = df_eq['depth'] > 300]['mag'].values]

#plt.scatter(x, y, categories, label=(shallow, deep))
#plt.title("Deep and Shallow Earthquakes")
#plt.xlabel('Shallow Earthquake Magnitude')  
#plt.ylabel('Deep Earthquake Magnitude')


# Create 5x6 figure
#plt.figure(figsize=[12, 6])

# Create a line plot
#plt.plot(x, y)
#plt.savefig('fig1.png')
# Out:
# /Users/Lilia/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#sns.distplot(df_eq['mag'])
